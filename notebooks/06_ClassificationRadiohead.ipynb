# %%
from ipynb.fs.full.Utils import load_dataset
import numpy as np
import pandas as pd
from sklearn import preprocessing
from matplotlib import pyplot as plt

# %%
from keras.models import load_model

# %%
model = load_model("classifier.h5")

# %%
data = pd.read_csv("Music_Dataset.csv")

# %%
data.head()
# Out:
#    id               album_uri     ...     track_popularity artist_name
# 0   1  0vE6mttRTBXRe9rKghyr1l     ...                 49.0      Eminem
# 1   2  0vE6mttRTBXRe9rKghyr1l     ...                 73.0      Eminem
# 2   3  0vE6mttRTBXRe9rKghyr1l     ...                 66.0      Eminem
# 3   4  0vE6mttRTBXRe9rKghyr1l     ...                 58.0      Eminem
# 4   5  0vE6mttRTBXRe9rKghyr1l     ...                  2.0      Eminem
#
# [5 rows x 25 columns]

# %%
relevant_cols = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', \
                     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', \
                     'duration_ms', 'time_signature']
data = data[relevant_cols]

# %%
data['mode'] = [0 if mode == 'minor' else 1 for mode in data['mode']]
data = pd.concat([data, pd.get_dummies(data['key'])], axis=1)
data = data.drop('key', axis = 1)

# %%
data.head()
# Out:
#    danceability  energy  loudness  mode  speechiness ...  E  F  F#  G  G#
# 0         0.648   0.199   -25.565     1        0.883 ...  0  0   0  0   0
# 1         0.869   0.680    -6.233     1        0.318 ...  0  0   0  0   0
# 2         0.660   0.789    -5.143     1        0.364 ...  0  0   0  1   0
# 3         0.866   0.599    -7.903     1        0.163 ...  0  0   0  0   0
# 4         0.816   0.266   -19.654     1        0.865 ...  0  0   0  0   1
#
# [5 rows x 24 columns]

# %%
x = data

# %%
x['danceability'] = [0 if np.isnan(d) else d for d in x['danceability']]
x['energy'] = [0 if np.isnan(d) else d for d in x['energy']]
x['loudness'] = [0 if np.isnan(d) else d for d in x['loudness']]
x['acousticness'] = [0 if np.isnan(d) else d for d in x['acousticness']]
x['speechiness'] = [0 if np.isnan(d) else d for d in x['speechiness']]
x['instrumentalness'] = [0 if np.isnan(d) else d for d in x['instrumentalness']]
x['liveness'] = [0 if np.isnan(d) else d for d in x['liveness']]
x['valence'] = [0 if np.isnan(d) else d for d in x['valence']]
x['tempo'] = [0 if np.isnan(d) else d for d in x['tempo']]
x['duration_ms'] = [0 if np.isnan(d) else d for d in x['duration_ms']]
x['time_signature'] = [0 if np.isnan(d) else d for d in x['time_signature']]

# %%
np.sum(x.isna())
# Out:
# danceability        0
# energy              0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# A                   0
# A#                  0
# B                   0
# C                   0
# C#                  0
# D                   0
# D#                  0
# E                   0
# F                   0
# F#                  0
# G                   0
# G#                  0
# dtype: int64

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %%
x.shape
# Out:
# (3608, 24)

# %%
y_predicted = model.predict(x)

# %%
np.max(y_predicted[3:5])
# Out:
# 0.39605024
