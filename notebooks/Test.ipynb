# %%
from ipynb.fs.full.Utils import load_dataset

# %%
df = load_dataset()

# %%
df
# Out:
#       album_release_year  album_popularity  danceability  energy key  \
# 0                   1999                69         0.648   0.199  C#
# 1                   1999                69         0.869   0.680  C#
# 2                   1999                69         0.660   0.789   G
# 3                   1999                69         0.866   0.599   D
# 4                   1999                69         0.816   0.266  G#
# 5                   1999                69         0.791   0.601   G
# 6                   1999                69         0.713   0.909   A
# 7                   1999                69         0.804   0.336  F#
# 8                   1999                69         0.865   0.589   G
# 9                   1999                69         0.303   0.376   E
# 10                  1999                69         0.754   0.631   B
# 11                  1999                69         0.780   0.368   F
# 12                  1999                69         0.887   0.758  C#
# ...
